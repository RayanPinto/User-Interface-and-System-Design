# %%
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Rayan\AppData\Local\Temp\ipykernel_5080\1953866677.py", line 51, in <lambda>
#     tk.Button(root, text="Vote Layout A", command=lambda: select_layout("Layout A")).grid(row=2, column=0, padx=20, pady=10)
#                                                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Rayan\AppData\Local\Temp\ipykernel_5080\1953866677.py", line 22, in select_layout
#     if r["Layout"] in p:
#        ~^^^^^^^^^^
# KeyError: 'Layout'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\tkinter\__init__.py", line 1962, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
# ...
