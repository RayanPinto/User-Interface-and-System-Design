# %%
import tkinter as tk
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
mouse_data=[]
def move(e):
    mouse_data.append([e.x,e.y,"move"])
    canvas.create_oval(e.x-1,e.y-1,e.x+1,e.y+1, fill="blue",outline="blue")
def click(e):
    mouse_data.append([e.x,e.y,"click"])
    canvas.create_oval(e.x-3,e.y-3,e.x+3,e.y+3, fill="red",outline="red")
root=tk.Tk()
root.geometry("500x600")
tk.Label(root,text="Mve ur mouse").pack()
canvas=tk.Canvas(root,width=450,height=300,bg="white")
canvas.pack(pady=10)
canvas.bind("<Motion>",move)
canvas.bind("<Button-1>",click)
tk.Button(root,text="Finish",command=root.destroy).pack(pady=10)
root.mainloop()
if mouse_data:
    df=pd.DataFrame(mouse_data,columns=["x","y","type"])
    plt.figure(figsize=(6,5))
    sns.kdeplot(data=df,x="x",y="y",cmap="reds",fill=True,thresh=0.05)
    plt.title("Mouse ")
    plt.gca().invert_yaxis()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 24
#      22 df=pd.DataFrame(mouse_data,columns=["x","y","type"])
#      23 plt.figure(figsize=(6,5))
# ---> 24 sns.kdeplot(data=df,x="x",y="y",cmap="reds",fill=True,thresh=0.05)
#      25 plt.title("Mouse ")
#      26 plt.gca().invert_yaxis()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1682, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
# -> 1682 color = _default_color(method, hue, color, kwargs)
# ...
