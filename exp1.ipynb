# %%
heuristic=[
    "User freedom and control",
    "Visibility of system status",
    "Match between system and real world",
    "Consistency and standards",
    "Error prevention",
    "Recognition rathan than recall",
    "flexibility and effiecieny of use",
    "Aesthetic and minimalist design",
    "Help user recover,diagnose from errors",
    "Help and documentation"
]
r=[]
for h in heuristic:
    print(h)
    while True:
        rating=int(input("Enter a value"))
        if 1<=rating<=5:
            r.append(rating)
            break
        else:
            print("Enter a correct rating")
avg=sum(r)/len(r)
print(avg)
# Out:
# User freedom and control
# Enter a value 0
# Enter a correct rating
# Enter a value 5
# Visibility of system status
# Enter a value 3
# Match between system and real world
# Enter a value 3
# Consistency and standards
# Enter a value 4
# Error prevention
# Enter a value 5
# Recognition rathan than recall
# Enter a value 5
# flexibility and effiecieny of use
# Enter a value 453
# Enter a correct rating
# Enter a value 33
# Enter a correct rating
# Enter a value 22
# Enter a correct rating
# Enter a value 21
# Enter a correct rating
# Enter a value 1
# Aesthetic and minimalist design
# Enter a value 2
# Help user recover,diagnose from errors
# Enter a value 3
# Help and documentation
# Enter a value 3
# 3.4
